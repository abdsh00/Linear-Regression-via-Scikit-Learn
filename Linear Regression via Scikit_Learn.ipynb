# %%
# !pip install matplotlib
# !pip install scikit-learn
# Out:
# Requirement already satisfied: matplotlib in d:\data_science_with_python\python\venv\lib\site-packages (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in d:\data_science_with_python\python\venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in d:\data_science_with_python\python\venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\data_science_with_python\python\venv\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\data_science_with_python\python\venv\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in d:\data_science_with_python\python\venv\lib\site-packages (from matplotlib) (2.3.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\engineeeeeeeeeeeer\appdata\roaming\python\python312\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in d:\data_science_with_python\python\venv\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\data_science_with_python\python\venv\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\engineeeeeeeeeeeer\appdata\roaming\python\python312\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\engineeeeeeeeeeeer\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: scikit-learn in d:\data_science_with_python\python\venv\lib\site-packages (1.7.2)
# Requirement already satisfied: numpy>=1.22.0 in d:\data_science_with_python\python\venv\lib\site-packages (from scikit-learn) (2.3.3)
# Requirement already satisfied: scipy>=1.8.0 in d:\data_science_with_python\python\venv\lib\site-packages (from scikit-learn) (1.16.2)
# Requirement already satisfied: joblib>=1.2.0 in d:\data_science_with_python\python\venv\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\data_science_with_python\python\venv\lib\site-packages (from scikit-learn) (3.6.0)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import SGDRegressor
from sklearn.preprocessing import StandardScaler
from lab_utils_multi import load_house_data
from lab_utils_common import dlc
np.set_printoptions(precision=2)

# %% [markdown]
# # Loading Data

# %%
X_train, y_train = load_house_data()
X_features = ['size(sqft)','bedrooms','floors','age']
print(y_train)
# Out:
# [300.   509.8  394.   540.   415.   230.   560.   294.   718.2  200.
#  302.   468.   374.2  388.   282.   311.8  401.   449.8  301.   502.
#  340.   400.28 572.   264.   304.   298.   219.8  490.7  216.96 368.2
#  280.   526.87 237.   562.43 369.8  460.   374.   390.   158.   426.
#  390.   277.77 216.96 425.8  504.   329.   464.   220.   358.   478.
#  334.   426.98 290.   463.   390.8  354.   350.   460.   237.   288.3
#  282.   249.   304.   332.   351.8  310.   216.96 666.34 330.   480.
#  330.3  348.   304.   384.   316.   430.4  450.   284.   275.   414.
#  258.   378.   350.   412.   373.   225.   390.   267.4  464.   174.
#  340.   430.   440.   216.   329.   388.   390.   356.   257.8 ]

# %% [markdown]
# # Z-Score Normalization

# %%
scalar = StandardScaler()
X_Norm = scalar.fit_transform(X_train)
print(f"Peak to Peak range by column in Raw        X:{np.ptp(X_train,axis=0)}")   
print(f"Peak to Peak range by column in Normalized X:{np.ptp(X_Norm,axis=0)}")
# Out:
# Peak to Peak range by column in Raw        X:[2.41e+03 4.00e+00 1.00e+00 9.50e+01]
# Peak to Peak range by column in Normalized X:[5.85 6.14 2.06 3.69]

# %% [markdown]
# # Model Training

# %%
sgdr = SGDRegressor(max_iter=1000)
sgdr.fit(X_Norm,y_train)
print(sgdr)
print(f"number of iterations completed: {sgdr.n_iter_}, number of weight updates: {sgdr.t_}")
# Out:
# SGDRegressor()
# number of iterations completed: 128, number of weight updates: 12673.0

# %%
b_norm = sgdr.intercept_
w_norm = sgdr.coef_

print("Model Parameters:")
print("b: ",b_norm)
print("w: ",w_norm)
# Out:
# Model Parameters:
# b:  [363.15]
# w:  [110.18 -21.1  -32.49 -38.02]

# %% [markdown]
# # Predictions

# %%
y_pred_sgdr = sgdr.predict(X_Norm)
y_pred = X_Norm @ w_norm + b_norm

print("Prediction via sgdr:\n",y_pred_sgdr)
print("Prediction via dot prod:\n",y_pred)
# Out:
# Prediction via sgdr:
#  [295.19 485.88 389.58 492.04 420.04 222.88 522.98 267.81 684.05 181.89
#  318.29 479.18 409.88 393.4  286.86 323.24 406.09 436.49 270.08 500.19
#  328.57 388.21 550.59 241.46 295.66 282.48 217.45 490.87 228.67 341.59
#  291.47 490.04 238.49 598.2  383.62 452.81 401.18 406.1  172.44 423.61
#  434.43 277.13 228.67 448.43 488.96 332.09 465.56 221.83 386.72 456.47
#  370.29 468.48 310.42 426.57 391.67 347.87 339.13 471.31 243.54 298.35
#  272.98 249.86 298.11 334.8  376.1  288.9  228.67 620.66 352.62 510.88
#  364.29 363.42 298.11 407.19 288.66 386.18 488.14 261.09 258.79 427.39
#  238.34 355.92 339.97 390.19 381.89 220.41 434.43 243.53 465.56 185.9
#  341.59 409.89 445.49 232.18 332.09 408.85 406.1  351.52 274.14]
# Prediction via dot prod:
#  [295.19 485.88 389.58 492.04 420.04 222.88 522.98 267.81 684.05 181.89
#  318.29 479.18 409.88 393.4  286.86 323.24 406.09 436.49 270.08 500.19
#  328.57 388.21 550.59 241.46 295.66 282.48 217.45 490.87 228.67 341.59
#  291.47 490.04 238.49 598.2  383.62 452.81 401.18 406.1  172.44 423.61
#  434.43 277.13 228.67 448.43 488.96 332.09 465.56 221.83 386.72 456.47
#  370.29 468.48 310.42 426.57 391.67 347.87 339.13 471.31 243.54 298.35
#  272.98 249.86 298.11 334.8  376.1  288.9  228.67 620.66 352.62 510.88
#  364.29 363.42 298.11 407.19 288.66 386.18 488.14 261.09 258.79 427.39
#  238.34 355.92 339.97 390.19 381.89 220.41 434.43 243.53 465.56 185.9
#  341.59 409.89 445.49 232.18 332.09 408.85 406.1  351.52 274.14]
